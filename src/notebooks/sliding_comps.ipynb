# %%
import sys
from pathlib import Path
import importlib.util

here = Path.cwd().resolve()
repo_root = next((p for p in (here, *here.parents) if (p / "src" / "__init__.py").exists()), None)
if repo_root is None:
    raise RuntimeError(f"Can't find repo root from {here}")

sys.path.insert(0, str(repo_root))

# %%
# Library imports
import numpy as np 
import pandas as pd 
import torch 
import torch.optim as optim 
from pathlib import Path 
import json
import matplotlib.pyplot as plt
import plotly.express as px


# Codebase imports
from src.models.lstm import LSTM 
from src.models.masked_lstm import MaskedLSTM
from src.models.trainer import Trainer
from src.models.masked_trainer import MaskedTrainer
from src.utils.loss_functions import RMSELoss
from src.utils.config_file_parser import config_file_parser
from src.utils.plot_predictions import plot_predictions
from src.utils.plot_losses import plot_loss_curves
from src.utils.datapipeline import DataPipeline
from src.utils.window_sizes.sliding_window_pipeline import SlidingWindowPipeline, SlidingWindowBatch
from src.interpretability.pfi import permutation_feature_importance
from src.interpretability.pfi_plots import plot_pfi_radar, plot_pfi_bar
from src.utils.metric_functions import rmse

# %% [markdown]
# # Sliding Window Analysis
# Per sliding window size, run each feature ~100 times to see how the distribution of errors are

# %%
# Change if needed
county_name = "Fresno"
rodent_flag = True
# Timestamp to track creation of run data
timestamp = pd.Timestamp.now().strftime("%Y-%m-%d_%H-%M-%S")
config_path = Path("../../config/masked_lstm_config.ini")
if rodent_flag:
  data_path   = Path(f"../../data/merged_rodent_{county_name.lower()}_agg.csv")
  run_dir     = Path(f"../../data/runs/{county_name.lower()}_Rat_{timestamp}")
else:
    data_path  = Path(f"../../data/{county_name.lower()}_Aggregate.csv")
    run_dir    = Path(f"../../data/runs/{county_name.lower()}_noRat_{timestamp}")

# run_dir.mkdir(parents=True, exist_ok=True)

# ------------- DO NOT TOUCH BELOW HERE --------------

# load config data
lstm_params, pipeline_params = config_file_parser(config_path=config_path)
hidden_size                  = int(lstm_params["hidden_size"])
num_layers                   = int(lstm_params["num_layers"])
dropout                      = float(lstm_params["dropout"])
learning_rate                = float(lstm_params["learning_rate"])
epochs                       = int(lstm_params["epochs"])
weight_decay                 = float(lstm_params["weight_decay"])
train_frac                   = float(lstm_params["train_frac"])
test_frac                    = 1 - train_frac

# import and clean the dataframe (remove date)
df = pd.read_csv(data_path)
for col in ["YEAR_MONTH", "Year-Month", "DATE"]:
    if col in df.columns:
      df = df.drop(columns = [col])

# Isolate the features I want
feature_columns = [col for col in df.columns if col != "VFRate"]

# Create the feature and target vectors
X = df[feature_columns].values
y = df["VFRate"].values 

########################################
#       Sliding Window Pipeline        #
########################################
# Create the datapipeline for sliding window calculations
pipeline = SlidingWindowPipeline(X, y, test_frac=test_frac)

# create a list of sliding window sizes from 1 to 12
sliding_window_sizes = [x for x in range(1,13)]
criterion = RMSELoss()

results = [] 
num_repeats = 100

for feat_idx, feat_name in enumerate(feature_columns):
  for win_size in sliding_window_sizes:
    batch : SlidingWindowBatch = pipeline.scale(*pipeline.create_single_feature_sequences(feat_idx, win_size))
    rmse_sw = []
    for run_idx in range(num_repeats):
      model = LSTM(
        input_size = 1,
        hidden_size= hidden_size, 
        num_layers= num_layers,
        dropout= dropout
      )
      
      optimizer = optim.Adam(model.parameters(), lr = learning_rate, weight_decay = weight_decay)
      trainer = Trainer(model=model, criterion=criterion, optimizer=optimizer, scaler_y = batch.scaler_y)
      
      trainer.train(X_train = batch.X_train, y_train = batch.y_train, epochs=epochs)
      preds, true = trainer.evaluate(batch.X_test, batch.y_test)
      
      rmse_sw.append(np.sqrt(np.mean((preds - true)**2)))
      
    results.append({
      "feature": feat_name, 
      "window_size": win_size,
      "rmse": rmse_sw
    })
    print(f"{feat_name:20s} | w={win_size:2d} | mean RMSE = {np.mean(rmse_sw):.4f} | std RMSE = {np.std(rmse_sw):.4f}")

results_df = pd.DataFrame(results)
print(results_df)
# best_vals = results_df.loc[results_df.groupby("feature")["rmse"].idxmin()]
# Out:
# FIRE_Acres_Burned    | w= 1 | mean RMSE = 2.6613 | std RMSE = 0.0285
# FIRE_Acres_Burned    | w= 2 | mean RMSE = 2.5770 | std RMSE = 0.0600
# FIRE_Acres_Burned    | w= 3 | mean RMSE = 2.2642 | std RMSE = 0.1805
# FIRE_Acres_Burned    | w= 4 | mean RMSE = 2.1982 | std RMSE = 0.1909
# FIRE_Acres_Burned    | w= 5 | mean RMSE = 2.4000 | std RMSE = 0.2390
# FIRE_Acres_Burned    | w= 6 | mean RMSE = 2.4528 | std RMSE = 0.2029
# FIRE_Acres_Burned    | w= 7 | mean RMSE = 1.7839 | std RMSE = 0.0860
# FIRE_Acres_Burned    | w= 8 | mean RMSE = 1.6013 | std RMSE = 0.1004
# FIRE_Acres_Burned    | w= 9 | mean RMSE = 1.3992 | std RMSE = 0.1061
# FIRE_Acres_Burned    | w=10 | mean RMSE = 1.4350 | std RMSE = 0.0894
# FIRE_Acres_Burned    | w=11 | mean RMSE = 1.3112 | std RMSE = 0.1851
# FIRE_Acres_Burned    | w=12 | mean RMSE = 1.4232 | std RMSE = 0.1861
# PRECIP               | w= 1 | mean RMSE = 2.7565 | std RMSE = 0.0243
# PRECIP               | w= 2 | mean RMSE = 2.8089 | std RMSE = 0.0540
# PRECIP               | w= 3 | mean RMSE = 2.8035 | std RMSE = 0.0791
# PRECIP               | w= 4 | mean RMSE = 2.7733 | std RMSE = 0.2103
# PRECIP               | w= 5 | mean RMSE = 2.7830 | std RMSE = 0.3410
# PRECIP               | w= 6 | mean RMSE = 2.5490 | std RMSE = 0.4630
# PRECIP               | w= 7 | mean RMSE = 3.0410 | std RMSE = 0.5769
# PRECIP               | w= 8 | mean RMSE = 2.6800 | std RMSE = 0.5003
# PRECIP               | w= 9 | mean RMSE = 1.8260 | std RMSE = 0.2574
# PRECIP               | w=10 | mean RMSE = 1.6539 | std RMSE = 0.5588
# PRECIP               | w=11 | mean RMSE = 1.3194 | std RMSE = 0.3381
# PRECIP               | w=12 | mean RMSE = 1.1933 | std RMSE = 0.1971
# WIND_EventCount      | w= 1 | mean RMSE = 2.8729 | std RMSE = 0.0296
# WIND_EventCount      | w= 2 | mean RMSE = 2.9078 | std RMSE = 0.0314
# WIND_EventCount      | w= 3 | mean RMSE = 2.9050 | std RMSE = 0.0434
# WIND_EventCount      | w= 4 | mean RMSE = 2.7942 | std RMSE = 0.1230
# WIND_EventCount      | w= 5 | mean RMSE = 2.6101 | std RMSE = 0.1984
# WIND_EventCount      | w= 6 | mean RMSE = 2.5176 | std RMSE = 0.2087
# WIND_EventCount      | w= 7 | mean RMSE = 2.4872 | std RMSE = 0.3447
# WIND_EventCount      | w= 8 | mean RMSE = 3.2012 | std RMSE = 0.4322
# WIND_EventCount      | w= 9 | mean RMSE = 2.9704 | std RMSE = 0.3933
# WIND_EventCount      | w=10 | mean RMSE = 2.7547 | std RMSE = 0.3542
# WIND_EventCount      | w=11 | mean RMSE = 2.6816 | std RMSE = 0.4243
# WIND_EventCount      | w=12 | mean RMSE = 2.5742 | std RMSE = 0.4917
# WIND_AvgMPH          | w= 1 | mean RMSE = 2.8495 | std RMSE = 0.0305
# WIND_AvgMPH          | w= 2 | mean RMSE = 2.9069 | std RMSE = 0.0554
# WIND_AvgMPH          | w= 3 | mean RMSE = 2.8747 | std RMSE = 0.0963
# WIND_AvgMPH          | w= 4 | mean RMSE = 2.7637 | std RMSE = 0.0883
# WIND_AvgMPH          | w= 5 | mean RMSE = 2.6651 | std RMSE = 0.1084
# WIND_AvgMPH          | w= 6 | mean RMSE = 2.7381 | std RMSE = 0.1189
# WIND_AvgMPH          | w= 7 | mean RMSE = 2.5388 | std RMSE = 0.4122
# WIND_AvgMPH          | w= 8 | mean RMSE = 2.4035 | std RMSE = 0.5206
# WIND_AvgMPH          | w= 9 | mean RMSE = 3.0508 | std RMSE = 0.8621
# WIND_AvgMPH          | w=10 | mean RMSE = 2.5564 | std RMSE = 0.6258
# WIND_AvgMPH          | w=11 | mean RMSE = 2.5226 | std RMSE = 0.6449
# WIND_AvgMPH          | w=12 | mean RMSE = 2.3247 | std RMSE = 0.5105
# WIND_RunMiles        | w= 1 | mean RMSE = 2.8467 | std RMSE = 0.0306
# WIND_RunMiles        | w= 2 | mean RMSE = 2.9010 | std RMSE = 0.0528
# WIND_RunMiles        | w= 3 | mean RMSE = 2.8752 | std RMSE = 0.0779
# WIND_RunMiles        | w= 4 | mean RMSE = 2.7557 | std RMSE = 0.0856
# WIND_RunMiles        | w= 5 | mean RMSE = 2.6732 | std RMSE = 0.1079
# WIND_RunMiles        | w= 6 | mean RMSE = 2.7395 | std RMSE = 0.1276
# WIND_RunMiles        | w= 7 | mean RMSE = 2.5391 | std RMSE = 0.4856
# WIND_RunMiles        | w= 8 | mean RMSE = 2.3818 | std RMSE = 0.4081
# WIND_RunMiles        | w= 9 | mean RMSE = 3.1688 | std RMSE = 0.8655
# WIND_RunMiles        | w=10 | mean RMSE = 2.5675 | std RMSE = 0.5419
# WIND_RunMiles        | w=11 | mean RMSE = 2.4071 | std RMSE = 0.5898
# WIND_RunMiles        | w=12 | mean RMSE = 2.2902 | std RMSE = 0.5370
# AQI_PM25             | w= 1 | mean RMSE = 2.7193 | std RMSE = 0.0269
# AQI_PM25             | w= 2 | mean RMSE = 2.7899 | std RMSE = 0.0580
# AQI_PM25             | w= 3 | mean RMSE = 2.8181 | std RMSE = 0.0740
# AQI_PM25             | w= 4 | mean RMSE = 2.8340 | std RMSE = 0.0858
# AQI_PM25             | w= 5 | mean RMSE = 2.9740 | std RMSE = 0.0685
# AQI_PM25             | w= 6 | mean RMSE = 3.1286 | std RMSE = 0.1285
# AQI_PM25             | w= 7 | mean RMSE = 3.2042 | std RMSE = 0.2539
# AQI_PM25             | w= 8 | mean RMSE = 3.1273 | std RMSE = 0.3642
# AQI_PM25             | w= 9 | mean RMSE = 3.1319 | std RMSE = 0.3822
# AQI_PM25             | w=10 | mean RMSE = 3.2378 | std RMSE = 0.4702
# AQI_PM25             | w=11 | mean RMSE = 3.0893 | std RMSE = 0.5291
# AQI_PM25             | w=12 | mean RMSE = 3.4005 | std RMSE = 0.7019
# AQI_PM10             | w= 1 | mean RMSE = 2.7533 | std RMSE = 0.0300
# AQI_PM10             | w= 2 | mean RMSE = 2.7725 | std RMSE = 0.0383
# AQI_PM10             | w= 3 | mean RMSE = 3.0335 | std RMSE = 0.1474
# AQI_PM10             | w= 4 | mean RMSE = 3.1148 | std RMSE = 0.3609
# AQI_PM10             | w= 5 | mean RMSE = 2.8826 | std RMSE = 0.4563
# AQI_PM10             | w= 6 | mean RMSE = 2.9055 | std RMSE = 0.3249
# AQI_PM10             | w= 7 | mean RMSE = 2.7844 | std RMSE = 0.3468
# AQI_PM10             | w= 8 | mean RMSE = 2.6038 | std RMSE = 0.2510
# AQI_PM10             | w= 9 | mean RMSE = 2.3710 | std RMSE = 0.2375
# AQI_PM10             | w=10 | mean RMSE = 1.8553 | std RMSE = 0.2805
# AQI_PM10             | w=11 | mean RMSE = 1.6064 | std RMSE = 0.3384
# AQI_PM10             | w=12 | mean RMSE = 1.9908 | std RMSE = 0.6037
# EARTHQUAKE_Total     | w= 1 | mean RMSE = 2.7711 | std RMSE = 0.0242
# EARTHQUAKE_Total     | w= 2 | mean RMSE = 2.7695 | std RMSE = 0.0466
# EARTHQUAKE_Total     | w= 3 | mean RMSE = 2.7639 | std RMSE = 0.0658
# EARTHQUAKE_Total     | w= 4 | mean RMSE = 2.7697 | std RMSE = 0.1276
# EARTHQUAKE_Total     | w= 5 | mean RMSE = 2.7730 | std RMSE = 0.1374
# EARTHQUAKE_Total     | w= 6 | mean RMSE = 2.8093 | std RMSE = 0.1320
# EARTHQUAKE_Total     | w= 7 | mean RMSE = 2.7651 | std RMSE = 0.2140
# EARTHQUAKE_Total     | w= 8 | mean RMSE = 2.7392 | std RMSE = 0.1869
# EARTHQUAKE_Total     | w= 9 | mean RMSE = 2.8859 | std RMSE = 0.4702
# EARTHQUAKE_Total     | w=10 | mean RMSE = 2.6412 | std RMSE = 0.2413
# EARTHQUAKE_Total     | w=11 | mean RMSE = 2.4458 | std RMSE = 0.2229
# EARTHQUAKE_Total     | w=12 | mean RMSE = 2.2911 | std RMSE = 0.3011
# PESTICIDE_Total      | w= 1 | mean RMSE = 2.7509 | std RMSE = 0.0510
# PESTICIDE_Total      | w= 2 | mean RMSE = 2.8112 | std RMSE = 0.0448
# PESTICIDE_Total      | w= 3 | mean RMSE = 2.9326 | std RMSE = 0.1265
# PESTICIDE_Total      | w= 4 | mean RMSE = 3.0471 | std RMSE = 0.2558
# PESTICIDE_Total      | w= 5 | mean RMSE = 2.8992 | std RMSE = 0.3763
# PESTICIDE_Total      | w= 6 | mean RMSE = 3.1697 | std RMSE = 0.3962
# PESTICIDE_Total      | w= 7 | mean RMSE = 3.0773 | std RMSE = 0.4098
# PESTICIDE_Total      | w= 8 | mean RMSE = 3.1443 | std RMSE = 0.6688
# PESTICIDE_Total      | w= 9 | mean RMSE = 3.2016 | std RMSE = 0.8570
# PESTICIDE_Total      | w=10 | mean RMSE = 3.3086 | std RMSE = 0.9508
# PESTICIDE_Total      | w=11 | mean RMSE = 2.9665 | std RMSE = 0.9460
# PESTICIDE_Total      | w=12 | mean RMSE = 2.5496 | std RMSE = 0.6845
# POUNDS_PRODUCT_APPLIED | w= 1 | mean RMSE = 2.7455 | std RMSE = 0.0210
# POUNDS_PRODUCT_APPLIED | w= 2 | mean RMSE = 2.7112 | std RMSE = 0.0513
# POUNDS_PRODUCT_APPLIED | w= 3 | mean RMSE = 2.6550 | std RMSE = 0.0775
# POUNDS_PRODUCT_APPLIED | w= 4 | mean RMSE = 2.7567 | std RMSE = 0.2323
# POUNDS_PRODUCT_APPLIED | w= 5 | mean RMSE = 2.8257 | std RMSE = 0.4910
# POUNDS_PRODUCT_APPLIED | w= 6 | mean RMSE = 2.9971 | std RMSE = 0.8190
# POUNDS_PRODUCT_APPLIED | w= 7 | mean RMSE = 3.1627 | std RMSE = 0.9502
# POUNDS_PRODUCT_APPLIED | w= 8 | mean RMSE = 2.5819 | std RMSE = 0.4149
# POUNDS_PRODUCT_APPLIED | w= 9 | mean RMSE = 2.5357 | std RMSE = 0.4691
# POUNDS_PRODUCT_APPLIED | w=10 | mean RMSE = 2.4644 | std RMSE = 0.6918
# POUNDS_PRODUCT_APPLIED | w=11 | mean RMSE = 2.5178 | std RMSE = 0.5531
# POUNDS_PRODUCT_APPLIED | w=12 | mean RMSE = 2.5948 | std RMSE = 0.3660
#                     feature  window_size  \
# 0         FIRE_Acres_Burned            1
# 1         FIRE_Acres_Burned            2
# 2         FIRE_Acres_Burned            3
# 3         FIRE_Acres_Burned            4
# 4         FIRE_Acres_Burned            5
# ..                      ...          ...
# 115  POUNDS_PRODUCT_APPLIED            8
# 116  POUNDS_PRODUCT_APPLIED            9
# 117  POUNDS_PRODUCT_APPLIED           10
# 118  POUNDS_PRODUCT_APPLIED           11
# 119  POUNDS_PRODUCT_APPLIED           12
#
#                                                   rmse
# 0    [2.6405623, 2.656766, 2.5671475, 2.7023757, 2....
# 1    [2.5735266, 2.5788581, 2.565687, 2.587831, 2.4...
# 2    [2.424119, 2.347275, 2.291928, 1.9557391, 2.16...
# 3    [2.387882, 2.275741, 2.1177576, 1.9950943, 2.1...
# 4    [2.2602243, 2.383441, 2.3777845, 2.476794, 2.3...
# ..                                                 ...
# 115  [3.4261851, 2.6443765, 2.5584419, 2.4390707, 3...
# 116  [2.2630255, 2.0662332, 2.0944045, 3.5544894, 2...
# 117  [3.0110822, 1.8441734, 1.9227821, 2.6416776, 1...
# 118  [2.5809386, 1.6632079, 2.289083, 2.0680046, 1....
# 119  [1.8999915, 2.591504, 2.5681355, 2.2652848, 2....
#
# [120 rows x 3 columns]

# %%
results_df
# Out:
#                     feature  window_size  \
# 0         FIRE_Acres_Burned            1
# 1         FIRE_Acres_Burned            2
# 2         FIRE_Acres_Burned            3
# 3         FIRE_Acres_Burned            4
# 4         FIRE_Acres_Burned            5
# ..                      ...          ...
# 115  POUNDS_PRODUCT_APPLIED            8
# 116  POUNDS_PRODUCT_APPLIED            9
# 117  POUNDS_PRODUCT_APPLIED           10
# 118  POUNDS_PRODUCT_APPLIED           11
# 119  POUNDS_PRODUCT_APPLIED           12
#
#                                                   rmse
# 0    [2.6405623, 2.656766, 2.5671475, 2.7023757, 2....
# 1    [2.5735266, 2.5788581, 2.565687, 2.587831, 2.4...
# 2    [2.424119, 2.347275, 2.291928, 1.9557391, 2.16...
# 3    [2.387882, 2.275741, 2.1177576, 1.9950943, 2.1...
# 4    [2.2602243, 2.383441, 2.3777845, 2.476794, 2.3...
# ..                                                 ...
# 115  [3.4261851, 2.6443765, 2.5584419, 2.4390707, 3...
# 116  [2.2630255, 2.0662332, 2.0944045, 3.5544894, 2...
# 117  [3.0110822, 1.8441734, 1.9227821, 2.6416776, 1...
# 118  [2.5809386, 1.6632079, 2.289083, 2.0680046, 1....
# 119  [1.8999915, 2.591504, 2.5681355, 2.2652848, 2....
#
# [120 rows x 3 columns]

# %%
df_long = results_df.explode("rmse", ignore_index=True)
print(df_long)
df_long["rmse"] = df_long["rmse"].astype(float)
df_long["run"]  = df_long.groupby(["feature", "window_size"]).cumcount()
print(df_long)
# Out:
#                       feature  window_size      rmse
# 0           FIRE_Acres_Burned            1  2.640562
# 1           FIRE_Acres_Burned            1  2.656766
# 2           FIRE_Acres_Burned            1  2.567147
# 3           FIRE_Acres_Burned            1  2.702376
# 4           FIRE_Acres_Burned            1    2.6513
# ...                       ...          ...       ...
# 11995  POUNDS_PRODUCT_APPLIED           12  2.037867
# 11996  POUNDS_PRODUCT_APPLIED           12  2.673531
# 11997  POUNDS_PRODUCT_APPLIED           12  2.223721
# 11998  POUNDS_PRODUCT_APPLIED           12  2.757697
# 11999  POUNDS_PRODUCT_APPLIED           12   4.21952
#
# [12000 rows x 3 columns]
#                       feature  window_size      rmse  run
# 0           FIRE_Acres_Burned            1  2.640562    0
# 1           FIRE_Acres_Burned            1  2.656766    1
# 2           FIRE_Acres_Burned            1  2.567147    2
# 3           FIRE_Acres_Burned            1  2.702376    3
# 4           FIRE_Acres_Burned            1  2.651300    4
# ...                       ...          ...       ...  ...
# 11995  POUNDS_PRODUCT_APPLIED           12  2.037867   95
# 11996  POUNDS_PRODUCT_APPLIED           12  2.673531   96
# 11997  POUNDS_PRODUCT_APPLIED           12  2.223721   97
# 11998  POUNDS_PRODUCT_APPLIED           12  2.757697   98
# 11999  POUNDS_PRODUCT_APPLIED           12  4.219520   99
#
# [12000 rows x 4 columns]

# %%
df_long.to_csv("../../data/rmse_trials_100runs.csv")
